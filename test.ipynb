# %%
import pandas as pd

# %%
df_population_data = pd.read_csv('data.csv',encoding='utf-8')

# %%
df_population_data
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 0                                                    0    全国   大正    9.0
# 1                                                    1   北海道   大正    9.0
# 2                                                    2   青森県   大正    9.0
# 3                                                    3   岩手県   大正    9.0
# 4                                                    4   宮城県   大正    9.0
# ..                                                 ...   ...  ...    ...
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注    人口（総数）     人口（男）     人口（女）
# ...

# %%
type(df_population_data)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_columns', 5) #最大表示列数

# %%
df_population_data
# Out:
#                                                都道府県コード 都道府県名  ...     人口（男）  \
# 0                                                   00    全国  ...  28044185
# 1                                                   01   北海道  ...   1244322
# 2                                                   02   青森県  ...    381293
# 3                                                   03   岩手県  ...    421069
# 4                                                   04   宮城県  ...    485309
# ..                                                 ...   ...  ...       ...
# 977                                                 45   宮崎県  ...    519242
# 978                                                 46  鹿児島県  ...    773061
# 979                                                 47   沖縄県  ...    704619
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  ...       NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  ...       NaN
#
#         人口（女）
# 0    27918868
# 1     1114861
# ...

# %%
pd.reset_option('display.max_columns')

# %%
df_population_data
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 0                                                   00    全国   大正    9.0
# 1                                                   01   北海道   大正    9.0
# 2                                                   02   青森県   大正    9.0
# 3                                                   03   岩手県   大正    9.0
# 4                                                   04   宮城県   大正    9.0
# ..                                                 ...   ...  ...    ...
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注    人口（総数）     人口（男）     人口（女）
# ...

# %%
df_population_data.head(10) #データの先頭から指定した行数分を表示（デフォルトで５件）
# Out:
#   都道府県コード 都道府県名  元号  和暦（年）   西暦（年）    注    人口（総数）     人口（男）     人口（女）
# 0      00    全国  大正    9.0  1920.0  NaN  55963053  28044185  27918868
# 1      01   北海道  大正    9.0  1920.0  NaN   2359183   1244322   1114861
# 2      02   青森県  大正    9.0  1920.0  NaN    756454    381293    375161
# 3      03   岩手県  大正    9.0  1920.0  NaN    845540    421069    424471
# 4      04   宮城県  大正    9.0  1920.0  NaN    961768    485309    476459
# 5      05   秋田県  大正    9.0  1920.0  NaN    898537    453682    444855
# 6      06   山形県  大正    9.0  1920.0  NaN    968925    478328    490597
# 7      07   福島県  大正    9.0  1920.0  NaN   1362750    673525    689225
# 8      08   茨城県  大正    9.0  1920.0  NaN   1350400    662128    688272
# 9      09   栃木県  大正    9.0  1920.0  NaN   1046479    514255    532224

# %%
df_population_data.tail(10) #データの末尾から指定した行数分を表示（デフォルトで５件）
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 972                                                 40   福岡県   平成   27.0
# 973                                                 41   佐賀県   平成   27.0
# 974                                                 42   長崎県   平成   27.0
# 975                                                 43   熊本県   平成   27.0
# 976                                                 44   大分県   平成   27.0
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注   人口（総数）    人口（男）    人口（女）
# 972  2015.0  NaN  5101556  2410418  2691138
# 973  2015.0  NaN   832832   393073   439759
# ...

# %%
df_population_data.sample(10) #ランダムに指定した行数分のデータを表示
# Out:
#     都道府県コード 都道府県名  元号  和暦（年）   西暦（年）    注   人口（総数）    人口（男）    人口（女）
# 769      37   香川県  平成    7.0  1995.0  NaN  1027006   493482   533524
# 208      16   富山県  昭和   15.0  1940.0  NaN   822569   401261   421308
# 148      04   宮城県  昭和   10.0  1935.0  NaN  1234801   622973   611828
# 810      28   兵庫県  平成   12.0  2000.0  NaN  5550574  2674625  2875949
# 948      16   富山県  平成   27.0  2015.0  NaN  1066328   515147   551181
# 739      07   福島県  平成    7.0  1995.0  NaN  2133592  1042030  1091562
# 805      23   愛知県  平成   12.0  2000.0  NaN  7043300  3525698  3517602
# 425      41   佐賀県  昭和   35.0  1960.0   2)   942874   448797   494077
# 305      17   石川県  昭和   25.0  1950.0  NaN   957279   460859   496420
# 554      22   静岡県  昭和   50.0  1975.0  NaN  3308799  1627797  1681002

# %%
df_population_data.info() #csvの情報を表示
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   都道府県コード  982 non-null    object
#  1   都道府県名    980 non-null    object
#  2   元号       980 non-null    object
#  3   和暦（年）    980 non-null    float64
#  4   西暦（年）    980 non-null    float64
#  5   注        96 non-null     object
#  6   人口（総数）   980 non-null    object
#  7   人口（男）    980 non-null    object
#  8   人口（女）    980 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 69.2+ KB

# %%
df_population_data.describe() #csvの要約統計量を表示
# Out:
#             和暦（年）        西暦（年）
# count  980.000000   980.000000
# mean    25.095918  1968.010204
# std     17.012192    28.841611
# min      2.000000  1920.000000
# 25%     12.000000  1945.000000
# 50%     22.000000  1970.000000
# 75%     40.000000  1995.000000
# max     60.000000  2015.000000

# %%
df_population_data.groupby(by='都道府県名').mean()[['人口（総数）', '人口（男）', '人口（女）']] #グルーピングして平均値を計算
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-eeb4f1ee11c0> in <module>
# ----> 1 df_population_data.groupby(by='都道府県名').mean()[['人口（総数）', '人口（男）', '人口（女）']] #グルーピングして平均値を計算
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
# ...

# %%
pd.to_numeric(df_population_data['人口（総数）'], 'coerce')
# Out:
# 0      55963053.0
# 1       2359183.0
# 2        756454.0
# 3        845540.0
# 4        961768.0
#           ...
# 977     1104069.0
# 978     1648177.0
# 979     1433566.0
# 980           NaN
# 981           NaN
# Name: 人口（総数）, Length: 982, dtype: float64

# %%
df_population_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   都道府県コード  982 non-null    object
#  1   都道府県名    980 non-null    object
#  2   元号       980 non-null    object
#  3   和暦（年）    980 non-null    float64
#  4   西暦（年）    980 non-null    float64
#  5   注        96 non-null     object
#  6   人口（総数）   980 non-null    object
#  7   人口（男）    980 non-null    object
#  8   人口（女）    980 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 69.2+ KB

# %%
df_population_data['人口（総数）'].str.replace('-', '0')
# Out:
# 0      55963053
# 1       2359183
# 2        756454
# 3        845540
# 4        961768
#          ...
# 977     1104069
# 978     1648177
# 979     1433566
# 980         NaN
# 981         NaN
# Name: 人口（総数）, Length: 982, dtype: object

# %%
df_population_data
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 0                                                    0    全国   大正    9.0
# 1                                                    1   北海道   大正    9.0
# 2                                                    2   青森県   大正    9.0
# 3                                                    3   岩手県   大正    9.0
# 4                                                    4   宮城県   大正    9.0
# ..                                                 ...   ...  ...    ...
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注    人口（総数）     人口（男）     人口（女）
# ...

# %%
df_population_data['人口（総数）'].astype('str')
# Out:
# 0      55963053
# 1       2359183
# 2        756454
# 3        845540
# 4        961768
#          ...
# 977     1104069
# 978     1648177
# 979     1433566
# 980         nan
# 981         nan
# Name: 人口（総数）, Length: 982, dtype: object

# %%
df_population_data['人口（総数）'].str.strip('NaN')
# Out:
# 0      55963053
# 1       2359183
# 2        756454
# 3        845540
# 4        961768
#          ...
# 977     1104069
# 978     1648177
# 979     1433566
# 980         NaN
# 981         NaN
# Name: 人口（総数）, Length: 982, dtype: object

# %%
df_population_data
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 0                                                    0    全国   大正    9.0
# 1                                                    1   北海道   大正    9.0
# 2                                                    2   青森県   大正    9.0
# 3                                                    3   岩手県   大正    9.0
# 4                                                    4   宮城県   大正    9.0
# ..                                                 ...   ...  ...    ...
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注    人口（総数）     人口（男）     人口（女）
# ...

# %%
pd.set_option('display.max_rows', 1000) #最大表示行数

# %%
df_population_data['人口（総数）']
# Out:
# 0       55963053
# 1        2359183
# 2         756454
# 3         845540
# 4         961768
# 5         898537
# 6         968925
# 7        1362750
# 8        1350400
# 9        1046479
# 10       1052610
# 11       1319533
# 12       1336155
# 13       3699428
# 14       1323390
# 15       1776474
# 16        724276
# 17        747360
# 18        599155
# 19        583453
# 20       1562722
# 21       1070407
# 22       1550387
# 23       2089762
# 24       1069270
# 25        651050
# 26       1287147
# 27       2587847
# 28       2301799
# 29        564607
# 30        750411
# 31        454675
# 32        714712
# 33       1217698
# 34       1541905
# 35       1041013
# 36        670212
# 37        677852
# 38       1046720
# 39        670895
# 40       2188249
# 41        673895
# 42       1136182
# 43       1233233
# 44        860282
# 45        651097
# 46       1415582
# 47        571572
# 48      59736822
# 49       2498679
# 50        812977
# 51        900984
# ...

# %%
#a = df_population_data['人口（総数）'].str.replace('-', '0').astype('float')
#df_population_data['人口（総数）'] = a

b = df_population_data['人口（男）'].str.replace('-', '0').astype('float')
df_population_data['人口（男）'] = b

c = df_population_data['人口（女'].str.replace('-', '0').astype('float')
df_population_data['人口（女'] = c
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '人口（女'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-46cf9cbd1653> in <module>
#       5 df_population_data['人口（男）'] = b
# ...

# %%
df_population_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   都道府県コード  982 non-null    object
#  1   都道府県名    980 non-null    object
#  2   元号       980 non-null    object
#  3   和暦（年）    980 non-null    float64
#  4   西暦（年）    980 non-null    float64
#  5   注        96 non-null     object
#  6   人口（総数）   980 non-null    float64
#  7   人口（男）    980 non-null    float64
#  8   人口（女）    980 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 69.2+ KB

# %%
c = df_population_data['人口（女）'].str.replace('-', '0').astype('float')
df_population_data['人口（女）'] = c

# %%
df_population_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   都道府県コード  982 non-null    object
#  1   都道府県名    980 non-null    object
#  2   元号       980 non-null    object
#  3   和暦（年）    980 non-null    float64
#  4   西暦（年）    980 non-null    float64
#  5   注        96 non-null     object
#  6   人口（総数）   980 non-null    float64
#  7   人口（男）    980 non-null    float64
#  8   人口（女）    980 non-null    float64
# dtypes: float64(5), object(4)
# memory usage: 69.2+ KB

# %%
df_population_data.describe().round(0)
# Out:
#        和暦（年）   西暦（年）       人口（総数）       人口（男）       人口（女）
# count  980.0   980.0        980.0       980.0       980.0
# mean    25.0  1968.0    5271083.0   2587337.0   2683746.0
# std     17.0    29.0   16548242.0   8119294.0   8429865.0
# min      2.0  1920.0          0.0         0.0         0.0
# 25%     12.0  1945.0    1022810.0    491736.0    525229.0
# 50%     22.0  1970.0    1509799.0    718963.0    780042.0
# 75%     40.0  1995.0    2367602.0   1160430.0   1212123.0
# max     60.0  2015.0  128057352.0  62348977.0  65729615.0

# %%
df_population_mean = df_population_data.groupby(by='都道府県名').mean()[['人口（総数）', '人口（男）', '人口（女）']].round(0) #グルーピングして平均値を計算

# %%
df_population_mean
# Out:
#                  人口（総数）       人口（男）       人口（女）
# 都道府県名
# 三重県           1534021.0    743367.0    790655.0
# 京都府           2135318.0   1044094.0   1091224.0
# 人口集中地区       76263636.0  37498317.0  38765320.0
# 人口集中地区以外の地区  45110512.0  21946810.0  23163701.0
# 佐賀県            830574.0    395551.0    435024.0
# 全国           98797992.0  48528468.0  50269525.0
# 兵庫県           4233525.0   2067583.0   2165942.0
# 北海道           4606104.0   2272235.0   2333869.0
# 千葉県           3591668.0   1789947.0   1801721.0
# 和歌山県           978371.0    471086.0    507286.0
# 埼玉県           4040109.0   2023428.0   2016681.0
# 大分県           1142165.0    544738.0    597427.0
# 大阪府           6380772.0   3167759.0   3213014.0
# 奈良県            993523.0    479186.0    514337.0
# 宮城県           1801086.0    884667.0    916418.0
# 宮崎県           1024880.0    492893.0    531986.0
# 富山県            993676.0    479457.0    514219.0
# 山口県           1433457.0    692875.0    740582.0
# ...

# %%
df_population_mean.sort_values(by='人口（総数）', ascending=False) #ソート
# Out:
#                  人口（総数）       人口（男）       人口（女）
# 都道府県名
# 全国           98797992.0  48528468.0  50269525.0
# 人口集中地区       76263636.0  37498317.0  38765320.0
# 人口集中地区以外の地区  45110512.0  21946810.0  23163701.0
# 東京都           9357393.0   4740644.0   4616749.0
# 大阪府           6380772.0   3167759.0   3213014.0
# 神奈川県          5072212.0   2582037.0   2490175.0
# 愛知県           4938295.0   2457583.0   2480712.0
# 北海道           4606104.0   2272235.0   2333869.0
# 兵庫県           4233525.0   2067583.0   2165942.0
# 埼玉県           4040109.0   2023428.0   2016681.0
# 福岡県           3927586.0   1903328.0   2024259.0
# 千葉県           3591668.0   1789947.0   1801721.0
# 静岡県           2892099.0   1422674.0   1469426.0
# 広島県           2347026.0   1146442.0   1200584.0
# 新潟県           2300825.0   1115898.0   1184927.0
# 茨城県           2249191.0   1110756.0   1138435.0
# 京都府           2135318.0   1044094.0   1091224.0
# 長野県           1984244.0    959837.0   1024408.0
# ...

# %%
import matplotlib

matplotlib.rcParams['font.family'] = 'Arial Unicode MS'

# %%
df_population_data[df_population_data['都道府県名']=='東京都'][['人口（男）', '人口（女）']].plot(color=['skyblue', 'pink'])
